# %%
def daftar_nama(nama):
  if nama in daftar_nama:
    return f"{nama}: sudah terdaftar."
    daftar_nama.append(nama)
    return f"{nama}: berhasil di tamabahkan."

def hapus_nama(nama):
  if nama in daftar_nama:
    daftar_nama.remove(nama)
    return f"{nama}: nama telah terhapus."
  return f"{nama}: tidak ditemukan."

def lihat_daftar(nama):
  if not daftar_nama:
    return "nama belum ditambahakn."
  if nama in daftar_nama:
    return "\n".join(daftar_nama)

def check_nama(nama):
  if nama in daftar_nama:
    return f"{nama}: nama terdaftar."
    return f"{nama}: tidak terdaftar."


daftar_nama = [ ]

while True:
  print("==MENU==")
  print("1. daftar nama")
  print("2. hapus nama")
  print("3. lihat daftar")
  print("4. chek nama")
  print("5. keluar")
  break

pilihan = input("masukan pilihan (1-5): ")

if pilihan == "1":
   nama = input("masukan nama: ")
   print(daftar_nama(nama))
elif pilihan == "2":
   nama = input("masukan nama yang ingin di hapus")
   print(hapus_nama(nama))
elif pilihan == "3":
     print("daftar nama")
     print(lihat_daftar(nama))
elif pilihan == "4":
     nama = input("masukan nama yang ingin di chek ")
     print(check_nama(nama))
elif pilihan == "5":
     print("program selesai")
    # break
else:
     print("pilihan tidak valid")
# Out:
# ==MENU==
# 1. daftar nama
# 2. hapus nama
# 3. lihat daftar
# 4. chek nama
# 5. keluar
# masukan pilihan (1-5): 4
# masukan nama yang ingin di chek falah
# None

# %% [markdown]
# # New Section
